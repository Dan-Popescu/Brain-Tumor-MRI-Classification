# %%
from pyspark.sql import SparkSession
from IPython.display import display

spark = SparkSession.builder.master("local[*]").appName("training-manifest").getOrCreate()
manifest_df = spark.read.parquet("../data/processed/manifest_bronze.parquet")
manifest_preview = manifest_df.limit(10).toPandas()
display(manifest_preview)
# Out:
#                                             image_id  \
# 0  e3d48efbb74908d45ed3ffdb1082b17d84da319d5b3927...
# 1  5900c3ad48d7a86e0c1e9567673024035a4213bc3f5411...
# 2  eadd90f001d097d16cfd2d44cf77191cdf99a58297589a...
# 3  8934e9e0fd3eb449e5f397a6529233bb2a3bcb088d0ced...
# 4  5ec4921d1e69e5707cc08be65abb1c93f8c76b2afdf364...
# 5  28cc83ade7df5c94c2c833360151566e84d0862342f46a...
# 6  d2bf0cd96d86150dc12df40cfda35eb7c870956e3dbb47...
# 7  1c3f326d12c6afd21dd99507cce36eeb7983bc656f8be8...
# 8  25033cda90afb41dfc5fa84dff4d1100a482265f206ce6...
# 9  7bbae095206f5662267faa1eccd09136ebd2e641bf2315...
#
#                                             raw_path  label_idx  file_size  \
# 0  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      57343
# 1  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      49838
# 2  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      35303
# 3  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      75811
# 4  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      49702
# 5  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      44996
# 6  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      56635
# 7  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      58112
# 8  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      48514
# 9  file:/home/dan/projects/ESGI/4A/T2/spark-core/...          8      56810
#
#    is_valid   pathology modality
# 0      True  Meningioma     T1C+
# 1      True  Meningioma     T1C+
# 2      True  Meningioma     T1C+
# 3      True  Meningioma     T1C+
# 4      True  Meningioma     T1C+
# 5      True  Meningioma     T1C+
# 6      True  Meningioma     T1C+
# 7      True  Meningioma     T1C+
# 8      True  Meningioma     T1C+
# 9      True  Meningioma     T1C+
